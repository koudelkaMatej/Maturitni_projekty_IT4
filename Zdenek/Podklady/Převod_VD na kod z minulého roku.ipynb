# %% [markdown]
# Euklidův algoritmus

# %%
def gcd(a, b):
    while b > 0:
        a, b = b, a % b
    return a

print(gcd(int(input("Zadejte první číslo ")), int(input("Zadejte první číslo "))))
# Out:
# Zadejte první číslo 133
# Zadejte první číslo 15
# 1
